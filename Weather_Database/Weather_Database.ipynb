# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import API key
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | bhadrachalam
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | cape coast
# Processing Record 10 of Set 1 | jumla
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | byron bay
# Processing Record 16 of Set 1 | pangnirtung
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | matara
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | inta
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | vestmanna
# Processing Record 30 of Set 1 | douglas
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 1 | lypova dolyna
# Processing Record 34 of Set 1 | alta floresta
# Processing Record 35 of Set 1 | vila velha
# Processing Record 36 of Set 1 | cabo san lucas
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | itoman
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | mayumba
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | veraval
# Processing Record 46 of Set 1 | novyy urgal
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | marienburg
# Processing Record 49 of Set 1 | aswan
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | westport
# Processing Record 2 of Set 2 | hirna
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 2 | almenara
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | griffith
# Processing Record 10 of Set 2 | pochutla
# Processing Record 11 of Set 2 | ostrovnoy
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | kurilsk
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | saurimo
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 2 | poum
# Processing Record 21 of Set 2 | rocha
# Processing Record 22 of Set 2 | clyde river
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | mehran
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | natal
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | novo aripuana
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | college
# Processing Record 32 of Set 2 | muli
# Processing Record 33 of Set 2 | ust-barguzin
# Processing Record 34 of Set 2 | uvinza
# Processing Record 35 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 36 of Set 2 | sawai madhopur
# Processing Record 37 of Set 2 | grand gaube
# Processing Record 38 of Set 2 | lons-le-saunier
# Processing Record 39 of Set 2 | itarema
# Processing Record 40 of Set 2 | paraiso
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | sao joao da barra
# Processing Record 45 of Set 2 | dingle
# Processing Record 46 of Set 2 | mangrol
# Processing Record 47 of Set 2 | souillac
# Processing Record 48 of Set 2 | los llanos de aridane
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | shimoda
# Processing Record 2 of Set 3 | isilkul
# Processing Record 3 of Set 3 | contamana
# Processing Record 4 of Set 3 | palmer
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | turukhansk
# Processing Record 7 of Set 3 | saldanha
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | tevaitoa
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | axim
# Processing Record 14 of Set 3 | nokaneng
# Processing Record 15 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 3 | monterey
# Processing Record 17 of Set 3 | temba
# Processing Record 18 of Set 3 | fairbanks
# Processing Record 19 of Set 3 | coquimbo
# Processing Record 20 of Set 3 | ibipeba
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | tres arroyos
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | hobyo
# Processing Record 26 of Set 3 | yar-sale
# Processing Record 27 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 3 | narasannapeta
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | burica
# City not found. Skipping...
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | sitka
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | tanabi
# Processing Record 37 of Set 3 | chernyshevskiy
# Processing Record 38 of Set 3 | ribas do rio pardo
# Processing Record 39 of Set 3 | san patricio
# Processing Record 40 of Set 3 | liverpool
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | beringovskiy
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | mwene-ditu
# Processing Record 45 of Set 3 | coahuayana
# Processing Record 46 of Set 3 | guanica
# Processing Record 47 of Set 3 | znamenskoye
# Processing Record 48 of Set 3 | bilibino
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | lasa
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | zapolyarnyy
# Processing Record 4 of Set 4 | gualaquiza
# Processing Record 5 of Set 4 | butaritari
# Processing Record 6 of Set 4 | bandarbeyla
# Processing Record 7 of Set 4 | taoudenni
# Processing Record 8 of Set 4 | mogadishu
# Processing Record 9 of Set 4 | madera
# Processing Record 10 of Set 4 | nelson bay
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | marsa matruh
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | umm lajj
# Processing Record 15 of Set 4 | darnah
# Processing Record 16 of Set 4 | los alamos
# Processing Record 17 of Set 4 | bengkulu
# Processing Record 18 of Set 4 | melfi
# Processing Record 19 of Set 4 | mpika
# Processing Record 20 of Set 4 | fort nelson
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | dikson
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | nizhniy kuranakh
# Processing Record 26 of Set 4 | rio gallegos
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | san quintin
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | jonacatepec
# Processing Record 31 of Set 4 | pemangkat
# Processing Record 32 of Set 4 | najran
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | xiaoweizhai
# Processing Record 35 of Set 4 | kansanshi
# Processing Record 36 of Set 4 | ayorou
# Processing Record 37 of Set 4 | pandan
# Processing Record 38 of Set 4 | husavik
# Processing Record 39 of Set 4 | pirot
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | camacha
# Processing Record 42 of Set 4 | minab
# Processing Record 43 of Set 4 | lata
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | jalpa
# Processing Record 46 of Set 4 | fonte boa
# Processing Record 47 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 4 | tokur
# Processing Record 49 of Set 4 | terrace
# Processing Record 50 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | goderich
# Processing Record 2 of Set 5 | mildura
# Processing Record 3 of Set 5 | viedma
# Processing Record 4 of Set 5 | discovery bay
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | pingxiang
# Processing Record 7 of Set 5 | porto belo
# Processing Record 8 of Set 5 | huilong
# Processing Record 9 of Set 5 | harnosand
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | prince george
# Processing Record 12 of Set 5 | illescas
# Processing Record 13 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 5 | mandurah
# Processing Record 15 of Set 5 | odweyne
# Processing Record 16 of Set 5 | linfen
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | nishihara
# Processing Record 19 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 5 | irricana
# Processing Record 21 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 5 | minot
# Processing Record 23 of Set 5 | skibbereen
# Processing Record 24 of Set 5 | karratha
# Processing Record 25 of Set 5 | stornoway
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 5 | sioux lookout
# Processing Record 29 of Set 5 | te anau
# Processing Record 30 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 5 | new norfolk
# Processing Record 32 of Set 5 | the valley
# Processing Record 33 of Set 5 | kanakapura
# Processing Record 34 of Set 5 | airai
# Processing Record 35 of Set 5 | tiblawan
# Processing Record 36 of Set 5 | avarua
# Processing Record 37 of Set 5 | comodoro rivadavia
# Processing Record 38 of Set 5 | muisne
# Processing Record 39 of Set 5 | praya
# Processing Record 40 of Set 5 | lorengau
# Processing Record 41 of Set 5 | cayenne
# Processing Record 42 of Set 5 | tiarei
# Processing Record 43 of Set 5 | mookane
# Processing Record 44 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 45 of Set 5 | kuching
# Processing Record 46 of Set 5 | high level
# Processing Record 47 of Set 5 | rafaela
# Processing Record 48 of Set 5 | latung
# Processing Record 49 of Set 5 | chegutu
# Processing Record 50 of Set 5 | flinders
# Processing Record 1 of Set 6 | nautla
# Processing Record 2 of Set 6 | lincoln
# Processing Record 3 of Set 6 | tura
# Processing Record 4 of Set 6 | almaznyy
# Processing Record 5 of Set 6 | port hardy
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 6 | abashiri
# Processing Record 9 of Set 6 | les cayes
# Processing Record 10 of Set 6 | la rioja
# Processing Record 11 of Set 6 | bhinmal
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | nueve de julio
# Processing Record 14 of Set 6 | ilulissat
# Processing Record 15 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 6 | dudinka
# Processing Record 17 of Set 6 | olinda
# Processing Record 18 of Set 6 | zheleznodorozhnyy
# Processing Record 19 of Set 6 | mount pleasant
# Processing Record 20 of Set 6 | xiuyan
# Processing Record 21 of Set 6 | bodden town
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | east london
# Processing Record 24 of Set 6 | boyolangu
# Processing Record 25 of Set 6 | luganville
# Processing Record 26 of Set 6 | araouane
# Processing Record 27 of Set 6 | yerbogachen
# Processing Record 28 of Set 6 | hervey bay
# Processing Record 29 of Set 6 | afua
# Processing Record 30 of Set 6 | platanos
# Processing Record 31 of Set 6 | vallenar
# Processing Record 32 of Set 6 | norman wells
# Processing Record 33 of Set 6 | westonaria
# Processing Record 34 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 6 | narsaq
# Processing Record 36 of Set 6 | turkistan
# Processing Record 37 of Set 6 | tolaga bay
# Processing Record 38 of Set 6 | carnarvon
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | laguna
# Processing Record 41 of Set 6 | urosevac
# City not found. Skipping...
# Processing Record 42 of Set 6 | vilhena
# Processing Record 43 of Set 6 | bukachacha
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | presidencia roque saenz pena
# Processing Record 46 of Set 6 | ahuimanu
# Processing Record 47 of Set 6 | conde
# Processing Record 48 of Set 6 | lagoa
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | solnechnyy
# Processing Record 1 of Set 7 | dunda
# Processing Record 2 of Set 7 | vila franca do campo
# Processing Record 3 of Set 7 | zamora
# Processing Record 4 of Set 7 | bouna
# Processing Record 5 of Set 7 | yenagoa
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | horsham
# Processing Record 8 of Set 7 | quatre cocos
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | naze
# Processing Record 11 of Set 7 | tucumcari
# Processing Record 12 of Set 7 | katobu
# Processing Record 13 of Set 7 | ippy
# Processing Record 14 of Set 7 | buraydah
# Processing Record 15 of Set 7 | ardon
# Processing Record 16 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 18 of Set 7 | basco
# Processing Record 19 of Set 7 | algiers
# Processing Record 20 of Set 7 | rongcheng
# Processing Record 21 of Set 7 | soyo
# Processing Record 22 of Set 7 | houston
# Processing Record 23 of Set 7 | kochki
# Processing Record 24 of Set 7 | clarence town
# Processing Record 25 of Set 7 | ancud
# Processing Record 26 of Set 7 | sidi bu zayd
# City not found. Skipping...
# Processing Record 27 of Set 7 | shelton
# Processing Record 28 of Set 7 | canete
# Processing Record 29 of Set 7 | pisco
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | talaya
# Processing Record 32 of Set 7 | bjelovar
# Processing Record 33 of Set 7 | kargapolye
# City not found. Skipping...
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | tonantins
# Processing Record 36 of Set 7 | vardo
# Processing Record 37 of Set 7 | semporna
# Processing Record 38 of Set 7 | beira
# Processing Record 39 of Set 7 | calvia
# Processing Record 40 of Set 7 | port macquarie
# Processing Record 41 of Set 7 | vanimo
# Processing Record 42 of Set 7 | whitehorse
# Processing Record 43 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 7 | two rivers
# Processing Record 45 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 7 | haapiti
# Processing Record 47 of Set 7 | candelaria
# Processing Record 48 of Set 7 | ganzhou
# Processing Record 49 of Set 7 | minnedosa
# Processing Record 50 of Set 7 | kaitong
# Processing Record 1 of Set 8 | morant bay
# Processing Record 2 of Set 8 | talara
# Processing Record 3 of Set 8 | tessalit
# Processing Record 4 of Set 8 | gravdal
# Processing Record 5 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 8 | mahibadhoo
# Processing Record 7 of Set 8 | belfast
# Processing Record 8 of Set 8 | nambucca heads
# Processing Record 9 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 10 of Set 8 | vostok
# Processing Record 11 of Set 8 | kota kinabalu
# Processing Record 12 of Set 8 | urzhum
# Processing Record 13 of Set 8 | huanuco
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | dunedin
# Processing Record 16 of Set 8 | bac lieu
# Processing Record 17 of Set 8 | nenjiang
# Processing Record 18 of Set 8 | ulladulla
# Processing Record 19 of Set 8 | horta
# Processing Record 20 of Set 8 | bossangoa
# Processing Record 21 of Set 8 | maarianhamina
# Processing Record 22 of Set 8 | yashkino
# Processing Record 23 of Set 8 | dhadar
# Processing Record 24 of Set 8 | mosquera
# Processing Record 25 of Set 8 | marshall
# Processing Record 26 of Set 8 | anadyr
# Processing Record 27 of Set 8 | batemans bay
# Processing Record 28 of Set 8 | kanniyakumari
# Processing Record 29 of Set 8 | lesnoye
# Processing Record 30 of Set 8 | champasak
# Processing Record 31 of Set 8 | ye
# City not found. Skipping...
# Processing Record 32 of Set 8 | bubaque
# Processing Record 33 of Set 8 | tecolutla
# Processing Record 34 of Set 8 | burgeo
# Processing Record 35 of Set 8 | maykor
# Processing Record 36 of Set 8 | faya
# Processing Record 37 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 8 | katsuura
# Processing Record 39 of Set 8 | komsomolskiy
# Processing Record 40 of Set 8 | helena
# Processing Record 41 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 8 | oreanda
# City not found. Skipping...
# Processing Record 44 of Set 8 | russell
# Processing Record 45 of Set 8 | dangriga
# Processing Record 46 of Set 8 | general roca
# Processing Record 47 of Set 8 | morondava
# Processing Record 48 of Set 8 | asyut
# Processing Record 49 of Set 8 | puerto del rosario
# Processing Record 50 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 9 | mocuba
# Processing Record 2 of Set 9 | singkawang
# Processing Record 3 of Set 9 | ulaangom
# Processing Record 4 of Set 9 | saint-francois
# Processing Record 5 of Set 9 | namibe
# Processing Record 6 of Set 9 | padang
# Processing Record 7 of Set 9 | kattivakkam
# Processing Record 8 of Set 9 | tapah
# Processing Record 9 of Set 9 | yumen
# Processing Record 10 of Set 9 | papetoai
# Processing Record 11 of Set 9 | boa vista
# Processing Record 12 of Set 9 | shelburne
# Processing Record 13 of Set 9 | batagay
# Processing Record 14 of Set 9 | zhigansk
# Processing Record 15 of Set 9 | valdivia
# Processing Record 16 of Set 9 | aranos
# Processing Record 17 of Set 9 | barreirinhas
# Processing Record 18 of Set 9 | berlevag
# Processing Record 19 of Set 9 | acapulco
# Processing Record 20 of Set 9 | khromtau
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | meulaboh
# Processing Record 23 of Set 9 | dalbandin
# Processing Record 24 of Set 9 | hami
# Processing Record 25 of Set 9 | lazo
# Processing Record 26 of Set 9 | madang
# Processing Record 27 of Set 9 | mentakab
# Processing Record 28 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 9 | poronaysk
# Processing Record 30 of Set 9 | tezu
# Processing Record 31 of Set 9 | biak
# Processing Record 32 of Set 9 | jasper
# Processing Record 33 of Set 9 | qaqortoq
# Processing Record 34 of Set 9 | pundaguitan
# Processing Record 35 of Set 9 | ilebo
# Processing Record 36 of Set 9 | caborca
# Processing Record 37 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 9 | makakilo city
# Processing Record 39 of Set 9 | haines junction
# Processing Record 40 of Set 9 | lexington park
# Processing Record 41 of Set 9 | murmashi
# Processing Record 42 of Set 9 | sungaipenuh
# Processing Record 43 of Set 9 | villamontes
# Processing Record 44 of Set 9 | elat
# Processing Record 45 of Set 9 | alanya
# Processing Record 46 of Set 9 | seymchan
# Processing Record 47 of Set 9 | kretinga
# Processing Record 48 of Set 9 | lubao
# Processing Record 49 of Set 9 | novikovo
# Processing Record 50 of Set 9 | jalu
# Processing Record 1 of Set 10 | khor
# Processing Record 2 of Set 10 | penzance
# Processing Record 3 of Set 10 | keti bandar
# Processing Record 4 of Set 10 | nioro
# Processing Record 5 of Set 10 | umm kaddadah
# Processing Record 6 of Set 10 | belmonte
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | khachrod
# Processing Record 9 of Set 10 | fortuna
# Processing Record 10 of Set 10 | jardim
# Processing Record 11 of Set 10 | nantong
# Processing Record 12 of Set 10 | obihiro
# Processing Record 13 of Set 10 | saint-pierre
# Processing Record 14 of Set 10 | coihaique
# Processing Record 15 of Set 10 | kefamenanu
# Processing Record 16 of Set 10 | tinskoy
# Processing Record 17 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 10 | sinnamary
# Processing Record 19 of Set 10 | lang son
# Processing Record 20 of Set 10 | bosaso
# Processing Record 21 of Set 10 | sao joao do paraiso
# Processing Record 22 of Set 10 | lichtenburg
# Processing Record 23 of Set 10 | billings
# Processing Record 24 of Set 10 | mooi river
# City not found. Skipping...
# Processing Record 25 of Set 10 | dwarka
# Processing Record 26 of Set 10 | xam nua
# Processing Record 27 of Set 10 | pazaric
# Processing Record 28 of Set 10 | wunsiedel
# Processing Record 29 of Set 10 | acarau
# Processing Record 30 of Set 10 | lakes entrance
# Processing Record 31 of Set 10 | ust-ilimsk
# Processing Record 32 of Set 10 | fuxin
# Processing Record 33 of Set 10 | cockburn town
# Processing Record 34 of Set 10 | avanigadda
# Processing Record 35 of Set 10 | margate
# Processing Record 36 of Set 10 | aksarka
# Processing Record 37 of Set 10 | mansa
# Processing Record 38 of Set 10 | atlantic city
# Processing Record 39 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 40 of Set 10 | buluang
# Processing Record 41 of Set 10 | lewistown
# Processing Record 42 of Set 10 | halifax
# Processing Record 43 of Set 10 | allingabro
# Processing Record 44 of Set 10 | sandayong
# Processing Record 45 of Set 10 | bermeo
# Processing Record 46 of Set 10 | sheridan
# Processing Record 47 of Set 10 | conceicao do araguaia
# Processing Record 48 of Set 10 | rawson
# Processing Record 49 of Set 10 | mehamn
# Processing Record 50 of Set 10 | smolenskoye
# Processing Record 1 of Set 11 | buala
# Processing Record 2 of Set 11 | broome
# Processing Record 3 of Set 11 | miyazu
# Processing Record 4 of Set 11 | nouadhibou
# Processing Record 5 of Set 11 | kailua
# Processing Record 6 of Set 11 | wahiawa
# Processing Record 7 of Set 11 | tignere
# Processing Record 8 of Set 11 | adrar
# Processing Record 9 of Set 11 | mount gambier
# Processing Record 10 of Set 11 | songjianghe
# Processing Record 11 of Set 11 | medford
# Processing Record 12 of Set 11 | grand island
# Processing Record 13 of Set 11 | tecoanapa
# Processing Record 14 of Set 11 | sterling
# Processing Record 15 of Set 11 | manzanillo
# Processing Record 16 of Set 11 | lethem
# Processing Record 17 of Set 11 | lieksa
# Processing Record 18 of Set 11 | klyuchi
# Processing Record 19 of Set 11 | isangel
# Processing Record 20 of Set 11 | oxford
# Processing Record 21 of Set 11 | fort frances
# Processing Record 22 of Set 11 | bumbuna
# Processing Record 23 of Set 11 | yazoo city
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | caceres
# Processing Record 26 of Set 11 | bojnurd
# Processing Record 27 of Set 11 | bunia
# Processing Record 28 of Set 11 | codrington
# Processing Record 29 of Set 11 | riviere-au-renard
# Processing Record 30 of Set 11 | port-gentil
# Processing Record 31 of Set 11 | tsarychanka
# Processing Record 32 of Set 11 | vestmannaeyjar
# Processing Record 33 of Set 11 | lesogorsk
# Processing Record 34 of Set 11 | uzhur-4
# City not found. Skipping...
# Processing Record 35 of Set 11 | tenenkou
# Processing Record 36 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 37 of Set 11 | puerto colombia
# Processing Record 38 of Set 11 | auki
# Processing Record 39 of Set 11 | sao raimundo das mangabeiras
# Processing Record 40 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 11 | tashtagol
# Processing Record 42 of Set 11 | barhi
# Processing Record 43 of Set 11 | nhulunbuy
# Processing Record 44 of Set 11 | gunjur
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 47 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 11 | kyabram
# Processing Record 49 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 11 | tilichiki
# Processing Record 1 of Set 12 | tautira
# Processing Record 2 of Set 12 | boyle
# Processing Record 3 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 4 of Set 12 | shenkursk
# Processing Record 5 of Set 12 | yashkul
# Processing Record 6 of Set 12 | baruun-urt
# Processing Record 7 of Set 12 | fernley
# Processing Record 8 of Set 12 | talnakh
# Processing Record 9 of Set 12 | bilma
# Processing Record 10 of Set 12 | mvuma
# Processing Record 11 of Set 12 | sumbe
# Processing Record 12 of Set 12 | frederico westphalen
# Processing Record 13 of Set 12 | kedarnath
# City not found. Skipping...
# Processing Record 14 of Set 12 | siparia
# Processing Record 15 of Set 12 | cartagena
# Processing Record 16 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 12 | uruzgan
# Processing Record 18 of Set 12 | kutum
# Processing Record 19 of Set 12 | balma
# Processing Record 20 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 12 | caramay
# Processing Record 22 of Set 12 | kandrian
# Processing Record 23 of Set 12 | pouembout
# Processing Record 24 of Set 12 | bo rai
# Processing Record 25 of Set 12 | teluk nibung
# Processing Record 26 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 12 | bathsheba
# Processing Record 28 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 12 | kuandian
# Processing Record 30 of Set 12 | sistranda
# Processing Record 31 of Set 12 | alamosa
# Processing Record 32 of Set 12 | christchurch
# Processing Record 33 of Set 12 | oktyabrskiy
# Processing Record 34 of Set 12 | hambantota
# Processing Record 35 of Set 12 | mareeba
# Processing Record 36 of Set 12 | novopokrovka
# Processing Record 37 of Set 12 | kichera
# Processing Record 38 of Set 12 | gizo
# Processing Record 39 of Set 12 | ayan
# Processing Record 40 of Set 12 | nemuro
# Processing Record 41 of Set 12 | beisfjord
# Processing Record 42 of Set 12 | masaurhi
# Processing Record 43 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 12 | ornskoldsvik
# Processing Record 45 of Set 12 | tocopilla
# Processing Record 46 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 12 | hudson bay
# Processing Record 48 of Set 12 | maceio
# Processing Record 49 of Set 12 | kamaishi
# Processing Record 50 of Set 12 | lahan
# Processing Record 1 of Set 13 | kathmandu
# Processing Record 2 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 13 | caucaia
# Processing Record 4 of Set 13 | newport
# Processing Record 5 of Set 13 | khairpur nathan shah
# Processing Record 6 of Set 13 | mtwango
# Processing Record 7 of Set 13 | antalya
# Processing Record 8 of Set 13 | swan hill
# Processing Record 9 of Set 13 | campina verde
# Processing Record 10 of Set 13 | corn island
# Processing Record 11 of Set 13 | cervo
# Processing Record 12 of Set 13 | gat
# Processing Record 13 of Set 13 | jurm
# Processing Record 14 of Set 13 | kikwit
# Processing Record 15 of Set 13 | euclides da cunha
# Processing Record 16 of Set 13 | kishtwar
# Processing Record 17 of Set 13 | sibolga
# Processing Record 18 of Set 13 | jakar
# Processing Record 19 of Set 13 | mandalgovi
# Processing Record 20 of Set 13 | macau
# Processing Record 21 of Set 13 | kawalu
# Processing Record 22 of Set 13 | aldan
# Processing Record 23 of Set 13 | hailar
# Processing Record 24 of Set 13 | hokitika
# Processing Record 25 of Set 13 | kysyl-syr
# Processing Record 26 of Set 13 | port hedland
# Processing Record 27 of Set 13 | channel-port aux basques
# Processing Record 28 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | thinadhoo
# Processing Record 30 of Set 13 | takoradi
# Processing Record 31 of Set 13 | cine
# Processing Record 32 of Set 13 | lazaro cardenas
# Processing Record 33 of Set 13 | tucuma
# Processing Record 34 of Set 13 | harrison
# Processing Record 35 of Set 13 | rabaul
# Processing Record 36 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 37 of Set 13 | west bay
# Processing Record 38 of Set 13 | avera
# Processing Record 39 of Set 13 | chicama
# Processing Record 40 of Set 13 | korla
# Processing Record 41 of Set 13 | villarrica
# Processing Record 42 of Set 13 | lufilufi
# Processing Record 43 of Set 13 | nantucket
# Processing Record 44 of Set 13 | zafra
# Processing Record 45 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 13 | kamina
# Processing Record 47 of Set 13 | floro
# Processing Record 48 of Set 13 | pangkalanbuun
# Processing Record 49 of Set 13 | kencong
# Processing Record 50 of Set 13 | tsumeb
# Processing Record 1 of Set 14 | howard springs
# Processing Record 2 of Set 14 | kermanshah
# Processing Record 3 of Set 14 | sassandra
# Processing Record 4 of Set 14 | kaeo
# Processing Record 5 of Set 14 | bose
# Processing Record 6 of Set 14 | nuuk
# Processing Record 7 of Set 14 | sala consilina
# Processing Record 8 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 14 | sobolevo
# Processing Record 10 of Set 14 | pangai
# Processing Record 11 of Set 14 | beipiao
# Processing Record 12 of Set 14 | carutapera
# Processing Record 13 of Set 14 | ulaanbaatar
# Processing Record 14 of Set 14 | amapa
# Processing Record 15 of Set 14 | palana
# Processing Record 16 of Set 14 | juxtlahuaca
# Processing Record 17 of Set 14 | methven
# Processing Record 18 of Set 14 | champerico
# Processing Record 19 of Set 14 | juneau
# Processing Record 20 of Set 14 | berdigestyakh
# Processing Record 21 of Set 14 | kunming
# Processing Record 22 of Set 14 | san jose de rio tinto
# Processing Record 23 of Set 14 | maltahohe
# Processing Record 24 of Set 14 | santa vitoria do palmar
# Processing Record 25 of Set 14 | sulphur
# Processing Record 26 of Set 14 | san ramon
# Processing Record 27 of Set 14 | requena
# Processing Record 28 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 29 of Set 14 | ardahan
# Processing Record 30 of Set 14 | raudeberg
# Processing Record 31 of Set 14 | gazli
# Processing Record 32 of Set 14 | boguchany
# Processing Record 33 of Set 14 | matay
# Processing Record 34 of Set 14 | muros
# Processing Record 35 of Set 14 | belaya gora
# Processing Record 36 of Set 14 | benguela
# Processing Record 37 of Set 14 | portland
# Processing Record 38 of Set 14 | atar
# Processing Record 39 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 14 | sulphur springs
# Processing Record 41 of Set 14 | middelburg
# Processing Record 42 of Set 14 | kieta
# Processing Record 43 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 14 | walvis bay
# Processing Record 45 of Set 14 | gemena
# Processing Record 46 of Set 14 | anjiang
# Processing Record 47 of Set 14 | ritchie
# Processing Record 48 of Set 14 | lahaina
# Processing Record 49 of Set 14 | yungkang
# City not found. Skipping...
# Processing Record 50 of Set 14 | saint-ambroise
# Processing Record 1 of Set 15 | mahuta
# Processing Record 2 of Set 15 | derzhavinsk
# Processing Record 3 of Set 15 | segou
# Processing Record 4 of Set 15 | tahe
# Processing Record 5 of Set 15 | at-bashi
# Processing Record 6 of Set 15 | marau
# Processing Record 7 of Set 15 | morehead
# Processing Record 8 of Set 15 | ilhabela
# Processing Record 9 of Set 15 | dasoguz
# Processing Record 10 of Set 15 | hauterive
# Processing Record 11 of Set 15 | neuquen
# Processing Record 12 of Set 15 | mutis
# Processing Record 13 of Set 15 | puerto leguizamo
# Processing Record 14 of Set 15 | sucre
# Processing Record 15 of Set 15 | ewa beach
# Processing Record 16 of Set 15 | dakar
# Processing Record 17 of Set 15 | leh
# Processing Record 18 of Set 15 | meadow lake
# Processing Record 19 of Set 15 | seoul
# Processing Record 20 of Set 15 | agadir
# Processing Record 21 of Set 15 | sorland
# Processing Record 22 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 23 of Set 15 | u thong
# Processing Record 24 of Set 15 | shu
# Processing Record 25 of Set 15 | hay river
# Processing Record 26 of Set 15 | antalaha
# Processing Record 27 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 15 | khandyga
# Processing Record 29 of Set 15 | kalmunai
# Processing Record 30 of Set 15 | palampur
# Processing Record 31 of Set 15 | husum
# Processing Record 32 of Set 15 | porto novo
# Processing Record 33 of Set 15 | libreville
# Processing Record 34 of Set 15 | nacala
# Processing Record 35 of Set 15 | anito
# Processing Record 36 of Set 15 | kidal
# Processing Record 37 of Set 15 | vasai
# Processing Record 38 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 15 | miri
# Processing Record 40 of Set 15 | aporawan
# City not found. Skipping...
# Processing Record 41 of Set 15 | bundaberg
# Processing Record 42 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 15 | cabedelo
# Processing Record 44 of Set 15 | lavumisa
# Processing Record 45 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 15 | yulara
# Processing Record 47 of Set 15 | dekoa
# City not found. Skipping...
# Processing Record 48 of Set 15 | peruibe
# Processing Record 49 of Set 15 | okha
# Processing Record 50 of Set 15 | port augusta
# Processing Record 1 of Set 16 | minoyan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata -38.0023  -57.5575     59.02        62           0
# 1   Bhadrachalam  17.6667   80.8833     74.34        97          99
# 2        Ushuaia -54.8000  -68.3000     27.61        96          65
# 3           Hilo  19.7297 -155.0900     76.80        91          90
# 4   Kruisfontein -34.0033   24.7314     49.89        60          87
# 5      Busselton -33.6500  115.3333     61.05        74         100
# 6         Faanui -16.4833 -151.7500     80.38        70          28
# 7   Punta Arenas -53.1500  -70.9167     39.31        70          40
# 8     Cape Coast   5.1053   -1.2466     78.58        88          63
# 9          Jumla  29.2747   82.1838     52.48        47          21
#
#    Wind Speed Country                 Date Current Description
# 0       11.99      AR  2021-10-17 00:05:59           clear sky
# 1        2.33      IN  2021-10-17 00:11:39     overcast clouds
# 2        4.59      AR  2021-10-17 00:00:44          light snow
# 3       10.36      US  2021-10-17 00:05:20       moderate rain
# 4       17.76      ZA  2021-10-17 00:08:42     overcast clouds
# 5        9.60      AU  2021-10-17 00:04:06     overcast clouds
# 6       19.28      PF  2021-10-17 00:05:45    scattered clouds
# 7        9.22      CL  2021-10-17 00:05:40    scattered clouds
# 8        9.48      GH  2021-10-17 00:11:40       broken clouds
# 9        5.46      NP  2021-10-17 00:04:12          few clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata      AR -38.0023  -57.5575     59.02        62           0
# 1   Bhadrachalam      IN  17.6667   80.8833     74.34        97          99
# 2        Ushuaia      AR -54.8000  -68.3000     27.61        96          65
# 3           Hilo      US  19.7297 -155.0900     76.80        91          90
# 4   Kruisfontein      ZA -34.0033   24.7314     49.89        60          87
# 5      Busselton      AU -33.6500  115.3333     61.05        74         100
# 6         Faanui      PF -16.4833 -151.7500     80.38        70          28
# 7   Punta Arenas      CL -53.1500  -70.9167     39.31        70          40
# 8     Cape Coast      GH   5.1053   -1.2466     78.58        88          63
# 9          Jumla      NP  29.2747   82.1838     52.48        47          21
#
#    Wind Speed Current Description
# 0       11.99           clear sky
# 1        2.33     overcast clouds
# 2        4.59          light snow
# 3       10.36       moderate rain
# 4       17.76     overcast clouds
# 5        9.60     overcast clouds
# 6       19.28    scattered clouds
# 7        9.22    scattered clouds
# 8        9.48       broken clouds
# 9        5.46          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
